# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/Volumes/part3/logo.png")

# %%
plt.imshow(img)

# %%
cv2.imshow('logo image',img) 
cv2.waitKey(5000)
cv2.destroyAllWindows()
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
gray = cv2.imread("/Volumes/part3/dog.png",cv2.IMREAD_GRAYSCALE)
cv2.imshow('Dog Image',gray)
cv2.waitKey(4000)
cv2.destroyAllWindows()
